# %%
.open tmp.db

# %%
-- Page 1: all fields in form order
select
  page,
  data ->> 'city_clerk_received_date',
  data ->> 'claim_number',
  data ->> 'claimant_name',
  data ->> 'claimant_date_of_birth',
  data ->> 'claimant_street_address',
  data ->> 'claimant_city',
  data ->> 'claimant_state',
  data ->> 'claimant_zip',
  data ->> 'social_security_number',
  data ->> 'drivers_license_number',
  data ->> 'phone_number',
  data ->> 'mail_notices_street_address',
  data ->> 'mail_notices_city',
  data ->> 'mail_notices_state',
  data ->> 'mail_notices_zip',
  data ->> 'claim_made_by_another_person',
  data ->> 'representative_name',
  data ->> 'representative_relationship',
  data ->> 'representative_address',
  data ->> 'representative_city',
  data ->> 'representative_state',
  data ->> 'representative_zip',
  data ->> 'person_is_minor',
  data ->> 'minor_birth_date',
  data ->> 'date_of_incident',
  data ->> 'time_of_incident',
  data ->> 'place_of_occurrence',
  data ->> 'general_description'
from extractions
where classifier_data ->> 'page_type' = 'claim_page1'
order by page;

# %%
-- Page 2: all fields in form order
select
  page,
  data ->> 'basis_is_city_employee_act',
  data ->> 'city_employee_name',
  data ->> 'city_employee_involvement_statement',
  data ->> 'basis_is_dangerous_condition',
  data ->> 'describe_public_property',
  data ->> 'date_of_notification',
  data ->> 'name_of_city_employee_notified',
  data ->> 'general_statement_of_incident',
  data ->> 'bodily_injury_claimed',
  data ->> 'physician_name_and_contact',
  data ->> 'hospital_name_and_contact',
  data ->> 'witnesses',
  data ->> 'incident_investigated_by_police',
  data ->> 'police_report_number',
  data ->> 'police_department_or_city',
  data ->> 'paramedics_called',
  data ->> 'paramedic_report_number',
  data ->> 'ambulance_company_name',
  data ->> 'claim_dollar_amount',
  data ->> 'executed_date',
  data ->> 'signature_name',
  data ->> 'signer_address'
from extractions
where classifier_data ->> 'page_type' = 'claim_page2'
order by page;
